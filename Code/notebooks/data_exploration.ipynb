# %% [markdown]
# ## Load Trip Data

# %%
import sys
import os

# Add the project root directory to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.data.load_data import load_trip_data
df = load_trip_data('../data/raw/fhvhv_tripdata_2025-02.parquet')

# %% [markdown]
# ## Preprocess

# %%
import importlib

import src.data.preprocess as preprocess
importlib.reload(preprocess)
from src.data.preprocess import preprocess_trip_data

# Read the Parquet file
df_processed = preprocess_trip_data(df)

df_processed
# Out:
# ============================================================
# NULL VALUE ANALYSIS SUMMARY
# ============================================================
# Total rows in dataset: 19,339,461
#
# Null values by column:
# ----------------------------------------
# originating_base_num: 4,906,388 (25.37%)
# on_scene_datetime: 4,906,388 (25.37%)
#
# Rows with at least one null value: 4,906,388 (25.37%)
#
# Null value patterns by company:
# ----------------------------------------
#
# Uber:
#   Total rows: 14,419,623
#
# Lyft:
#   Total rows: 4,919,838
#   originating_base_num: 4,906,388 (99.73%)
#   on_scene_datetime: 4,906,388 (99.73%)
#
# Temporal patterns of null values:
# ----------------------------------------
# Date range of entries with nulls:
#   Earliest: 2025-02-01 00:00:01
#   Latest: 2025-02-28 23:59:59
#
# Most common null value patterns:
# ----------------------------------------
#   Null in ['originating_base_num', 'on_scene_datetime']: 4,906,388 rows (25.37%)
#
# ============================================================
#          originating_base_num    request_datetime   on_scene_datetime  \
# 0                      B03404 2025-01-31 23:59:37 2025-02-01 00:02:18
# 1                      B03404 2025-02-01 00:03:52 2025-02-01 00:09:57
# 2                      B03404 2025-02-01 00:30:46 2025-02-01 00:33:02
# 3                      B03404 2025-02-01 00:33:01 2025-02-01 00:33:09
# 4                      B03404 2025-02-01 00:51:19 2025-02-01 00:53:04
# ...                       ...                 ...                 ...
# 19339456                 None 2025-02-28 23:11:00                 NaT
# 19339457                 None 2025-02-28 23:34:58                 NaT
# 19339458                 None 2025-02-28 23:43:26                 NaT
# 19339459               B03404 2025-02-28 22:59:34 2025-02-28 23:02:57
# 19339460               B03404 2025-02-28 23:14:29 2025-02-28 23:35:41
#
#              pickup_datetime    dropoff_datetime  PULocationID  DOLocationID  \
# 0        2025-02-01 00:03:15 2025-02-01 00:07:02           233           170
# 1        2025-02-01 00:10:11 2025-02-01 00:36:32           107            47
# 2        2025-02-01 00:34:30 2025-02-01 01:00:56           237           249
# 3        2025-02-01 00:35:10 2025-02-01 00:48:22           263           151
# 4        2025-02-01 00:54:11 2025-02-01 01:26:01           238            33
# ...                      ...                 ...           ...           ...
# 19339456 2025-02-28 23:17:01 2025-02-28 23:36:51            74           164
# 19339457 2025-02-28 23:40:16 2025-02-28 23:47:23           234           114
# 19339458 2025-02-28 23:48:46 2025-03-01 00:01:41           114             4
# 19339459 2025-02-28 23:04:25 2025-02-28 23:33:30           231           163
# 19339460 2025-02-28 23:37:42 2025-03-01 00:06:39           230             7
#
#           trip_miles  trip_time  base_passenger_fare  ...  driver_pay  \
# 0              1.020        227                10.02  ...        4.26
# 1              8.710       1581                38.93  ...       27.21
# 2              5.120       1586                52.70  ...       32.39
# 3              2.370        792                16.52  ...       10.91
# 4             10.810       1910                34.37  ...       33.26
# ...              ...        ...                  ...  ...         ...
# 19339456       5.907       1190                25.52  ...       20.42
# 19339457       1.353        427                19.40  ...        9.25
# 19339458       1.409        775                18.62  ...       12.85
# 19339459       5.490       1746                65.17  ...       31.99
# 19339460       8.700       1737                64.43  ...       34.89
#
#           shared_request_flag  shared_match_flag  access_a_ride_flag  \
# 0                           N                  N                   N
# 1                           N                  N                   N
# 2                           N                  N                   N
# 3                           N                  N                   N
# 4                           N                  N                   N
# ...                       ...                ...                 ...
# 19339456                    N                  N                   N
# 19339457                    N                  N                   N
# 19339458                    N                  N                   N
# 19339459                    N                  N                   N
# 19339460                    N                  N                   N
#
#           wav_request_flag  wav_match_flag  cbd_congestion_fee company  \
# 0                        N               N                 1.5    Uber
# 1                        N               N                 1.5    Uber
# 2                        N               N                 1.5    Uber
# 3                        N               N                 0.0    Uber
# 4                        N               N                 0.0    Uber
# ...                    ...             ...                 ...     ...
# 19339456                 N               N                 1.5    Lyft
# 19339457                 N               N                 1.5    Lyft
# 19339458                 N               N                 1.5    Lyft
# 19339459                 N               N                 1.5    Uber
# 19339460                 N               N                 1.5    Uber
#
#          pickup_weekday dropoff_weekday
# 0              Saturday        Saturday
# 1              Saturday        Saturday
# 2              Saturday        Saturday
# 3              Saturday        Saturday
# 4              Saturday        Saturday
# ...                 ...             ...
# 19339456         Friday          Friday
# 19339457         Friday          Friday
# 19339458         Friday        Saturday
# 19339459         Friday          Friday
# 19339460         Friday        Saturday
#
# [19339461 rows x 26 columns]

# %% [markdown]
# ## Summary Statistics

# %%
pd.set_option('display.max_columns', None)
df_processed.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.set_option('display.max_columns', None)
#       2 df_processed.head()
#
# NameError: name 'pd' is not defined
